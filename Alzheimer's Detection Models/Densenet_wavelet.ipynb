# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
import skimage.io
import os 
import tqdm
import glob
import tensorflow 
import pywt
import cv2

from tqdm import tqdm
from sklearn.utils import shuffle
from sklearn import metrics
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import Model
from tensorflow.keras.layers import InputLayer, BatchNormalization, Dropout, Flatten, Dense, Activation, MaxPool2D, Conv2D, Input
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.applications.vgg16 import VGG16 # VGG16
from tensorflow.keras.applications.vgg19 import VGG19 # VGG19
from tensorflow.keras.applications.resnet50 import ResNet50 # ResNet50
from tensorflow.keras.applications.xception import Xception # Xception
from tensorflow.keras.applications.mobilenet import MobileNet # MobileNet
from tensorflow.keras.applications.nasnet import NASNetMobile # NASNetMobile
from tensorflow.keras.applications.densenet import DenseNet169 # DenseNet169
from tensorflow.keras.applications.densenet import DenseNet121 # DenseNet121
from tensorflow.keras.applications.mobilenet_v2 import MobileNetV2 # MobileNetV2
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.utils import to_categorical
from keras import optimizers

import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, BatchNormalization, Dropout, Flatten, Dense, Activation, MaxPool2D, Conv2D
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.applications.vgg16 import VGG16 # VGG16
from tensorflow.keras.applications.vgg19 import VGG19 # VGG19
from tensorflow.keras.applications.resnet50 import ResNet50 # ResNet50
from tensorflow.keras.applications.xception import Xception # Xception
from tensorflow.keras.applications.mobilenet import MobileNet # MobileNet
from tensorflow.keras.applications.nasnet import NASNetMobile # NASNetMobile
from tensorflow.keras.applications.densenet import DenseNet169 # DenseNet169
from tensorflow.keras.applications.densenet import DenseNet121 # DenseNet121
from tensorflow.keras.applications.mobilenet_v2 import MobileNetV2 # MobileNetV2
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.utils import to_categorical
from keras import optimizers
import tensorflow.keras.backend as K

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Unziping the dataset

# !unzip -q "/content/drive/MyDrive/Garvin/IEEE/Alzheimer's Disease Classification/Dataset.zip"

# %%
def wavelet_transform(image):
    image = cv2.resize(image,(image.shape[0]*2,image.shape[1]*2))
    coeff_f = []
    for i in range(image.shape[-1]):
        c1,(c2,c3,c4) = pywt.dwt2(image[:,:,i], wavelet = 'db3', mode = 'periodization')
        coeff_f.append(c1)
        coeff_f.append(c2)
        coeff_f.append(c3)
        # coeff_f.append(c4)
        return np.moveaxis(np.array(coeff_f),0,-1)

train_datagen = ImageDataGenerator(rescale = 1./255,
                                   validation_split = 0.2,                         
                                   rotation_range=5,
                                   width_shift_range=0.2,
                                   height_shift_range=0.2,
                                   shear_range=0.2,
                                   #zoom_range=0.2,
                                   horizontal_flip=True,
                                   vertical_flip=True,
                                   fill_mode='nearest',
                                   preprocessing_function = wavelet_transform)

valid_datagen = ImageDataGenerator(rescale = 1./255,
                                  validation_split = 0.2,
                                   preprocessing_function = wavelet_transform)

test_datagen  = ImageDataGenerator(rescale = 1./255,
                                   preprocessing_function = wavelet_transform)

# %%
train_dataset  = train_datagen.flow_from_directory(directory = '/content/Alzheimer_s Dataset/train',
                                                   target_size = (224,224),
                                                   class_mode = 'categorical',
                                                   subset = 'training',
                                                   batch_size = 32)

valid_dataset = valid_datagen.flow_from_directory(directory = '/content/Alzheimer_s Dataset/train',
                                                  target_size = (224,224),
                                                  class_mode = 'categorical',
                                                  subset = 'validation',
                                                  batch_size = 32)

test_dataset = test_datagen.flow_from_directory(directory = '/content/Alzheimer_s Dataset/test',
                                                  target_size = (224,224),
                                                  class_mode = 'categorical',
                                                  batch_size = 32)
# Out:
# Found 4098 images belonging to 4 classes.
# Found 1023 images belonging to 4 classes.
# Found 1279 images belonging to 4 classes.

# %%
# input_mri_image = Input(batch_shape = (16,224,224,12))
# n1 = Conv2D(filters = 12, kernel_size = (4,4), padding = 'same', activation = 'relu')(input_mri_image)
# n2 = Conv2D(filters = 6, kernel_size = (4,4), padding = 'same', activation = 'relu')(n1)
# n3 = Conv2D(filters = 3, kernel_size = (4,4), padding = 'same', activation = 'relu')(n2)

# pre_model = Model(inputs = [input_mri_image], outputs = [n3])

# base_model = DenseNet121( input_shape=(224,224,3),
#                    include_top=False,
#                    weights="imagenet")

# def get_densenet():
#   densenet_model = DenseNet121(
#                    include_top=False,
#                    weights="imagenet")
#   for layer in densenet_model.layers:
#     layer.trainable=False
#   return densenet_model

# def get_pre_model():

#   input_mri_image = Input(batch_shape = (16,224,224,12))
#   n1 = Conv2D(filters = 12, kernel_size = (3,3), padding = 'same', activation = 'relu')(input_mri_image)
#   n2 = Conv2D(filters = 6, kernel_size = (3,3), padding = 'same', activation = 'relu')(n1)
#   n3 = Conv2D(filters = 3, kernel_size = (3,3), padding = 'same', activation = 'relu')(n2)

#   pre_model = Model(inputs = input_mri_image, outputs = n1)
#   return pre_model

# def get_post_model():

#   model=Sequential()
#   # model.add(pre_model)
#   # model.add(base_model)
#   model.add(Dropout(0.5))
#   model.add(Flatten())
#   model.add(BatchNormalization())
#   model.add(Dense(64,kernel_initializer='he_uniform'))
#   model.add(BatchNormalization())
#   model.add(Activation('relu'))
#   model.add(Dropout(0.5))
#   model.add(Dense(64,kernel_initializer='he_uniform'))
#   model.add(BatchNormalization())
#   model.add(Activation('relu'))
#   model.add(Dropout(0.5))
#   model.add(Dense(64,kernel_initializer='he_uniform'))
#   model.add(BatchNormalization())
#   model.add(Activation('relu'))
#   model.add(Dropout(0.5))
#   model.add(Dense(32,kernel_initializer='he_uniform'))
#   model.add(BatchNormalization())
#   model.add(Activation('relu'))
#   model.add(Dropout(0.5))
#   model.add(Dense(32,kernel_initializer='he_uniform'))
#   model.add(BatchNormalization())
#   model.add(Activation('relu'))
#   model.add(Dense(4,activation='softmax'))

#   return model

# def get_model():
#   pre_model = get_pre_model()
#   densenet_model = get_densenet()
#   post_model = get_post_model()

#   input_mri_image = Input(batch_shape=(16,224,224,12))

#   pre_model.compile(optimizer='rmsprop', loss='categorical_crossentropy',metrics=METRICS)
#   densenet_model.compile(optimizer='rmsprop', loss='categorical_crossentropy',metrics=METRICS)
#   post_model.compile(optimizer='rmsprop', loss='categorical_crossentropy',metrics=METRICS)

#   wavelet_feature_images = pre_model(input_mri_image)
#   result_densenet = densenet_model(wavelet_feature_images)
#   output_result = post_model(result_densenet)

#   model = Model(inputs=input_mri_image, outputs = output_result)
#   model.compile(optimizer='rmsprop', loss='categorical_crossentropy',metrics=METRICS)

#   return model, pre_model


# model, pre_model = get_model()

# %%
# input_mri_image = Input(batch_shape = (16,224,224,12))
# n1 = Conv2D(filters = 12, kernel_size = (4,4), padding = 'same', activation = 'relu')(input_mri_image)
# n2 = Conv2D(filters = 6, kernel_size = (4,4), padding = 'same', activation = 'relu')(n1)
# n3 = Conv2D(filters = 3, kernel_size = (4,4), padding = 'same', activation = 'relu')(n2)

# pre_model = Model(inputs = [input_mri_image], outputs = [n3])

base_model = DenseNet121( input_shape=(224,224,3),
                   include_top=False,
                   weights="imagenet")

for layer in base_model.layers:
    layer.trainable=False

model=Sequential()
model.add(base_model)
model.add(Dropout(0.5))
model.add(Flatten())
model.add(BatchNormalization())
model.add(Dense(64,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(64,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(64,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(32,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(32,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dense(4,activation='softmax'))

model.build((None,224,224,3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29089792/29084464 [==============================] - 0s 0us/step
# 29097984/29084464 [==============================] - 0s 0us/step

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# densenet121 (Functional)     (None, 7, 7, 1024)        7037504
# _________________________________________________________________
# dropout (Dropout)            (None, 7, 7, 1024)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 50176)             0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 50176)             200704
# _________________________________________________________________
# dense (Dense)                (None, 64)                3211328
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 64)                256
# _________________________________________________________________
# activation (Activation)      (None, 64)                0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                4160
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 64)                256
# _________________________________________________________________
# activation_1 (Activation)    (None, 64)                0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                4160
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 64)                256
# _________________________________________________________________
# activation_2 (Activation)    (None, 64)                0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 32)                2080
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 32)                128
# _________________________________________________________________
# activation_3 (Activation)    (None, 32)                0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 32)                1056
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 32)                128
# _________________________________________________________________
# activation_4 (Activation)    (None, 32)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 4)                 132
# =================================================================
# Total params: 10,462,148
# Trainable params: 3,323,780
# Non-trainable params: 7,138,368
# _________________________________________________________________

# %%
def f1_score(y_true, y_pred): #taken from old keras source code
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

# %%
METRICS = [
      tf.keras.metrics.BinaryAccuracy(name='accuracy'),
      tf.keras.metrics.Precision(name='precision'),
      tf.keras.metrics.Recall(name='recall'),  
      tf.keras.metrics.AUC(name='auc'),
      f1_score,
]

# %%
def exponential_decay(lr0, s):
    def exponential_decay_fn(epoch):
        return lr0 * 0.1 **(epoch / s)
    return exponential_decay_fn

exponential_decay_fn = exponential_decay(0.01, 5) # when i run it for 50 epochs

lr_scheduler = tf.keras.callbacks.LearningRateScheduler(exponential_decay_fn)

# %%
weights_file=os.path.join("/content/drive/MyDrive/Garvin/IEEE/Alzheimer's Disease Classification/model_densenet_wavelet.hdf5")
 
checkpoint = ModelCheckpoint(weights_file, monitor='val_accuracy', verbose=1, 
                             save_best_only=True, mode='max', save_weights_only = True)

callbacks= [checkpoint, lr_scheduler]

# %%
model.compile(optimizer='rmsprop', loss='categorical_crossentropy',metrics=METRICS)

# %%
history=model.fit(train_dataset,
                  validation_data=valid_dataset,
                  epochs = 100,
                  verbose = 1,
                  callbacks=callbacks)
# Out:
# Epoch 1/100
# 129/129 [==============================] - 130s 691ms/step - loss: 1.1120 - accuracy: 0.7432 - precision: 0.4722 - recall: 0.2326 - auc: 0.7598 - f1_score: 0.3082 - val_loss: 1.0170 - val_accuracy: 0.7867 - val_precision: 0.6068 - val_recall: 0.4164 - val_auc: 0.8209 - val_f1_score: 0.4923
#
# Epoch 00001: val_accuracy improved from -inf to 0.78666, saving model to /content/drive/MyDrive/Garvin/IEEE/Alzheimer's Disease Classification/model_densenet_wavelet.hdf5
# Epoch 2/100
# 129/129 [==============================] - 84s 649ms/step - loss: 1.0532 - accuracy: 0.7560 - precision: 0.5273 - recall: 0.2333 - auc: 0.7797 - f1_score: 0.3173 - val_loss: 1.0218 - val_accuracy: 0.7783 - val_precision: 0.6593 - val_recall: 0.2346 - val_auc: 0.8063 - val_f1_score: 0.3415
#
# Epoch 00002: val_accuracy did not improve from 0.78666
# Epoch 3/100
# 129/129 [==============================] - 85s 658ms/step - loss: 1.0435 - accuracy: 0.7574 - precision: 0.5357 - recall: 0.2218 - auc: 0.7849 - f1_score: 0.3099 - val_loss: 1.0163 - val_accuracy: 0.7769 - val_precision: 0.7477 - val_recall: 0.1623 - val_auc: 0.8064 - val_f1_score: 0.2614
#
# Epoch 00003: val_accuracy did not improve from 0.78666
# Epoch 4/100
# 129/129 [==============================] - 87s 670ms/step - loss: 1.0242 - accuracy: 0.7655 - precision: 0.5923 - recall: 0.1989 - auc: 0.7936 - f1_score: 0.2916 - val_loss: 1.0159 - val_accuracy: 0.7686 - val_precision: 0.8455 - val_recall: 0.0909 - val_auc: 0.8051 - val_f1_score: 0.1612
#
# Epoch 00004: val_accuracy did not improve from 0.78666
# Epoch 5/100
# 129/129 [==============================] - 84s 650ms/step - loss: 1.0093 - accuracy: 0.7717 - precision: 0.6330 - recall: 0.2062 - auc: 0.7996 - f1_score: 0.3073 - val_loss: 1.0263 - val_accuracy: 0.7647 - val_precision: 0.9167 - val_recall: 0.0645 - val_auc: 0.8046 - val_f1_score: 0.1174
#
# Epoch 00005: val_accuracy did not improve from 0.78666
# Epoch 6/100
# 129/129 [==============================] - 84s 649ms/step - loss: 1.0098 - accuracy: 0.7725 - precision: 0.6326 - recall: 0.2147 - auc: 0.8001 - f1_score: 0.3204 - val_loss: 1.0302 - val_accuracy: 0.7622 - val_precision: 0.9032 - val_recall: 0.0547 - val_auc: 0.8010 - val_f1_score: 0.1006
#
# Epoch 00006: val_accuracy did not improve from 0.78666
# Epoch 7/100
# 129/129 [==============================] - 85s 658ms/step - loss: 0.9987 - accuracy: 0.7765 - precision: 0.6605 - recall: 0.2184 - auc: 0.8039 - f1_score: 0.3245 - val_loss: 1.0305 - val_accuracy: 0.7625 - val_precision: 0.9048 - val_recall: 0.0557 - val_auc: 0.7977 - val_f1_score: 0.1036
#
# Epoch 00007: val_accuracy did not improve from 0.78666
# Epoch 8/100
# 129/129 [==============================] - 87s 672ms/step - loss: 0.9941 - accuracy: 0.7786 - precision: 0.6764 - recall: 0.2194 - auc: 0.8055 - f1_score: 0.3311 - val_loss: 1.0213 - val_accuracy: 0.7678 - val_precision: 0.9011 - val_recall: 0.0802 - val_auc: 0.8063 - val_f1_score: 0.1453
#
# Epoch 00008: val_accuracy did not improve from 0.78666
# Epoch 9/100
# 129/129 [==============================] - 84s 654ms/step - loss: 0.9857 - accuracy: 0.7822 - precision: 0.6872 - recall: 0.2365 - auc: 0.8075 - f1_score: 0.3517 - val_loss: 1.0170 - val_accuracy: 0.7693 - val_precision: 0.8990 - val_recall: 0.0870 - val_auc: 0.8079 - val_f1_score: 0.1553
#
# Epoch 00009: val_accuracy did not improve from 0.78666
# Epoch 10/100
# 129/129 [==============================] - 84s 651ms/step - loss: 0.9988 - accuracy: 0.7789 - precision: 0.6751 - recall: 0.2225 - auc: 0.8042 - f1_score: 0.3344 - val_loss: 1.0218 - val_accuracy: 0.7676 - val_precision: 0.9000 - val_recall: 0.0792 - val_auc: 0.8036 - val_f1_score: 0.1432
#
# Epoch 00010: val_accuracy did not improve from 0.78666
# Epoch 11/100
# 129/129 [==============================] - 83s 642ms/step - loss: 0.9883 - accuracy: 0.7814 - precision: 0.6868 - recall: 0.2306 - auc: 0.8079 - f1_score: 0.3483 - val_loss: 1.0243 - val_accuracy: 0.7671 - val_precision: 0.8977 - val_recall: 0.0772 - val_auc: 0.8035 - val_f1_score: 0.1387
#
# Epoch 00011: val_accuracy did not improve from 0.78666
# Epoch 12/100
# 129/129 [==============================] - 84s 648ms/step - loss: 0.9977 - accuracy: 0.7808 - precision: 0.6839 - recall: 0.2291 - auc: 0.8082 - f1_score: 0.3442 - val_loss: 1.0213 - val_accuracy: 0.7678 - val_precision: 0.9011 - val_recall: 0.0802 - val_auc: 0.8061 - val_f1_score: 0.1442
#
# Epoch 00012: val_accuracy did not improve from 0.78666
# Epoch 13/100
# 129/129 [==============================] - 85s 655ms/step - loss: 0.9854 - accuracy: 0.7809 - precision: 0.6825 - recall: 0.2308 - auc: 0.8097 - f1_score: 0.3482 - val_loss: 1.0184 - val_accuracy: 0.7688 - val_precision: 0.9053 - val_recall: 0.0841 - val_auc: 0.8083 - val_f1_score: 0.1503
#
# Epoch 00013: val_accuracy did not improve from 0.78666
# Epoch 14/100
# 129/129 [==============================] - 85s 654ms/step - loss: 0.9918 - accuracy: 0.7797 - precision: 0.6805 - recall: 0.2240 - auc: 0.8051 - f1_score: 0.3405 - val_loss: 1.0226 - val_accuracy: 0.7674 - val_precision: 0.8989 - val_recall: 0.0782 - val_auc: 0.8063 - val_f1_score: 0.1408
#
# Epoch 00014: val_accuracy did not improve from 0.78666
# Epoch 15/100
# 129/129 [==============================] - 85s 662ms/step - loss: 0.9889 - accuracy: 0.7801 - precision: 0.6795 - recall: 0.2277 - auc: 0.8085 - f1_score: 0.3375 - val_loss: 1.0196 - val_accuracy: 0.7683 - val_precision: 0.9032 - val_recall: 0.0821 - val_auc: 0.8084 - val_f1_score: 0.1481
#
# Epoch 00015: val_accuracy did not improve from 0.78666
# Epoch 16/100
# 129/129 [==============================] - 86s 662ms/step - loss: 0.9916 - accuracy: 0.7784 - precision: 0.6676 - recall: 0.2260 - auc: 0.8078 - f1_score: 0.3333 - val_loss: 1.0213 - val_accuracy: 0.7681 - val_precision: 0.9022 - val_recall: 0.0811 - val_auc: 0.8057 - val_f1_score: 0.1438
#
# Epoch 00016: val_accuracy did not improve from 0.78666
# Epoch 17/100
# 129/129 [==============================] - 84s 654ms/step - loss: 0.9879 - accuracy: 0.7807 - precision: 0.6834 - recall: 0.2291 - auc: 0.8085 - f1_score: 0.3439 - val_loss: 1.0175 - val_accuracy: 0.7693 - val_precision: 0.9072 - val_recall: 0.0860 - val_auc: 0.8076 - val_f1_score: 0.1545
#
# Epoch 00017: val_accuracy did not improve from 0.78666
# Epoch 18/100
# 129/129 [==============================] - 84s 650ms/step - loss: 0.9919 - accuracy: 0.7800 - precision: 0.6783 - recall: 0.2279 - auc: 0.8087 - f1_score: 0.3428 - val_loss: 1.0169 - val_accuracy: 0.7698 - val_precision: 0.9091 - val_recall: 0.0880 - val_auc: 0.8088 - val_f1_score: 0.1576
#
# Epoch 00018: val_accuracy did not improve from 0.78666
# Epoch 19/100
# 129/129 [==============================] - 83s 646ms/step - loss: 0.9832 - accuracy: 0.7822 - precision: 0.6944 - recall: 0.2301 - auc: 0.8115 - f1_score: 0.3470 - val_loss: 1.0163 - val_accuracy: 0.7696 - val_precision: 0.9000 - val_recall: 0.0880 - val_auc: 0.8094 - val_f1_score: 0.1560
#
# Epoch 00019: val_accuracy did not improve from 0.78666
# Epoch 20/100
# 129/129 [==============================] - 83s 640ms/step - loss: 0.9911 - accuracy: 0.7793 - precision: 0.6786 - recall: 0.2225 - auc: 0.8076 - f1_score: 0.3311 - val_loss: 1.0167 - val_accuracy: 0.7696 - val_precision: 0.9000 - val_recall: 0.0880 - val_auc: 0.8093 - val_f1_score: 0.1578
#
# Epoch 00020: val_accuracy did not improve from 0.78666
# Epoch 21/100
# 129/129 [==============================] - 82s 636ms/step - loss: 0.9904 - accuracy: 0.7808 - precision: 0.6863 - recall: 0.2269 - auc: 0.8072 - f1_score: 0.3422 - val_loss: 1.0188 - val_accuracy: 0.7688 - val_precision: 0.9053 - val_recall: 0.0841 - val_auc: 0.8077 - val_f1_score: 0.1513
#
# Epoch 00021: val_accuracy did not improve from 0.78666
# Epoch 22/100
# 129/129 [==============================] - 82s 638ms/step - loss: 0.9914 - accuracy: 0.7806 - precision: 0.6822 - recall: 0.2289 - auc: 0.8106 - f1_score: 0.3457 - val_loss: 1.0194 - val_accuracy: 0.7683 - val_precision: 0.9032 - val_recall: 0.0821 - val_auc: 0.8068 - val_f1_score: 0.1481
#
# Epoch 00022: val_accuracy did not improve from 0.78666
# Epoch 23/100
# 129/129 [==============================] - 83s 642ms/step - loss: 0.9910 - accuracy: 0.7811 - precision: 0.6878 - recall: 0.2274 - auc: 0.8085 - f1_score: 0.3378 - val_loss: 1.0211 - val_accuracy: 0.7681 - val_precision: 0.9022 - val_recall: 0.0811 - val_auc: 0.8066 - val_f1_score: 0.1461
#
# Epoch 00023: val_accuracy did not improve from 0.78666
# Epoch 24/100
# 129/129 [==============================] - 83s 642ms/step - loss: 0.9824 - accuracy: 0.7814 - precision: 0.6884 - recall: 0.2296 - auc: 0.8099 - f1_score: 0.3458 - val_loss: 1.0206 - val_accuracy: 0.7681 - val_precision: 0.9022 - val_recall: 0.0811 - val_auc: 0.8069 - val_f1_score: 0.1455
#
# Epoch 00024: val_accuracy did not improve from 0.78666
# Epoch 25/100
# 129/129 [==============================] - 84s 651ms/step - loss: 0.9897 - accuracy: 0.7807 - precision: 0.6848 - recall: 0.2274 - auc: 0.8085 - f1_score: 0.3415 - val_loss: 1.0177 - val_accuracy: 0.7693 - val_precision: 0.9072 - val_recall: 0.0860 - val_auc: 0.8102 - val_f1_score: 0.1552
#
# Epoch 00025: val_accuracy did not improve from 0.78666
# Epoch 26/100
# 129/129 [==============================] - 83s 639ms/step - loss: 0.9863 - accuracy: 0.7806 - precision: 0.6860 - recall: 0.2255 - auc: 0.8110 - f1_score: 0.3358 - val_loss: 1.0208 - val_accuracy: 0.7681 - val_precision: 0.9022 - val_recall: 0.0811 - val_auc: 0.8078 - val_f1_score: 0.1450
#
# Epoch 00026: val_accuracy did not improve from 0.78666
# Epoch 27/100
# 129/129 [==============================] - 82s 637ms/step - loss: 0.9864 - accuracy: 0.7813 - precision: 0.6890 - recall: 0.2282 - auc: 0.8105 - f1_score: 0.3390 - val_loss: 1.0203 - val_accuracy: 0.7681 - val_precision: 0.9022 - val_recall: 0.0811 - val_auc: 0.8070 - val_f1_score: 0.1462
#
# Epoch 00027: val_accuracy did not improve from 0.78666
# Epoch 28/100
# 129/129 [==============================] - 83s 644ms/step - loss: 0.9829 - accuracy: 0.7816 - precision: 0.6933 - recall: 0.2267 - auc: 0.8092 - f1_score: 0.3449 - val_loss: 1.0199 - val_accuracy: 0.7683 - val_precision: 0.9032 - val_recall: 0.0821 - val_auc: 0.8072 - val_f1_score: 0.1480
#
# Epoch 00028: val_accuracy did not improve from 0.78666
# Epoch 29/100
# 129/129 [==============================] - 84s 657ms/step - loss: 0.9950 - accuracy: 0.7793 - precision: 0.6719 - recall: 0.2294 - auc: 0.8069 - f1_score: 0.3413 - val_loss: 1.0177 - val_accuracy: 0.7693 - val_precision: 0.9072 - val_recall: 0.0860 - val_auc: 0.8089 - val_f1_score: 0.1535
#
# Epoch 00029: val_accuracy did not improve from 0.78666
# Epoch 30/100
# 129/129 [==============================] - 84s 650ms/step - loss: 0.9827 - accuracy: 0.7833 - precision: 0.7004 - recall: 0.2328 - auc: 0.8109 - f1_score: 0.3490 - val_loss: 1.0217 - val_accuracy: 0.7678 - val_precision: 0.9011 - val_recall: 0.0802 - val_auc: 0.8072 - val_f1_score: 0.1423
#
# Epoch 00030: val_accuracy did not improve from 0.78666
# Epoch 31/100
# 129/129 [==============================] - 84s 648ms/step - loss: 0.9865 - accuracy: 0.7800 - precision: 0.6783 - recall: 0.2279 - auc: 0.8088 - f1_score: 0.3411 - val_loss: 1.0209 - val_accuracy: 0.7681 - val_precision: 0.9022 - val_recall: 0.0811 - val_auc: 0.8072 - val_f1_score: 0.1463
#
# Epoch 00031: val_accuracy did not improve from 0.78666
# Epoch 32/100
# 129/129 [==============================] - 83s 645ms/step - loss: 0.9986 - accuracy: 0.7777 - precision: 0.6707 - recall: 0.2177 - auc: 0.8079 - f1_score: 0.3251 - val_loss: 1.0207 - val_accuracy: 0.7681 - val_precision: 0.9022 - val_recall: 0.0811 - val_auc: 0.8090 - val_f1_score: 0.1461
#
# Epoch 00032: val_accuracy did not improve from 0.78666
# Epoch 33/100
# 129/129 [==============================] - 83s 644ms/step - loss: 0.9902 - accuracy: 0.7806 - precision: 0.6811 - recall: 0.2304 - auc: 0.8067 - f1_score: 0.3447 - val_loss: 1.0222 - val_accuracy: 0.7678 - val_precision: 0.9011 - val_recall: 0.0802 - val_auc: 0.8075 - val_f1_score: 0.1435
#
# Epoch 00033: val_accuracy did not improve from 0.78666
# Epoch 34/100
# 129/129 [==============================] - 84s 649ms/step - loss: 0.9921 - accuracy: 0.7792 - precision: 0.6786 - recall: 0.2221 - auc: 0.8055 - f1_score: 0.3349 - val_loss: 1.0220 - val_accuracy: 0.7681 - val_precision: 0.9022 - val_recall: 0.0811 - val_auc: 0.8060 - val_f1_score: 0.1468
#
# Epoch 00034: val_accuracy did not improve from 0.78666
# Epoch 35/100
# 129/129 [==============================] - 82s 637ms/step - loss: 0.9895 - accuracy: 0.7806 - precision: 0.6819 - recall: 0.2291 - auc: 0.8078 - f1_score: 0.3440 - val_loss: 1.0181 - val_accuracy: 0.7696 - val_precision: 0.9082 - val_recall: 0.0870 - val_auc: 0.8096 - val_f1_score: 0.1539
#
# Epoch 00035: val_accuracy did not improve from 0.78666
# Epoch 36/100
# 129/129 [==============================] - 83s 643ms/step - loss: 0.9806 - accuracy: 0.7807 - precision: 0.6875 - recall: 0.2255 - auc: 0.8112 - f1_score: 0.3391 - val_loss: 1.0205 - val_accuracy: 0.7681 - val_precision: 0.9022 - val_recall: 0.0811 - val_auc: 0.8080 - val_f1_score: 0.1449
#
# Epoch 00036: val_accuracy did not improve from 0.78666
# Epoch 37/100
# 129/129 [==============================] - 82s 636ms/step - loss: 0.9814 - accuracy: 0.7796 - precision: 0.6763 - recall: 0.2274 - auc: 0.8096 - f1_score: 0.3415 - val_loss: 1.0171 - val_accuracy: 0.7698 - val_precision: 0.9091 - val_recall: 0.0880 - val_auc: 0.8090 - val_f1_score: 0.1576
#
# Epoch 00037: val_accuracy did not improve from 0.78666
# Epoch 38/100
# 129/129 [==============================] - 82s 638ms/step - loss: 0.9869 - accuracy: 0.7806 - precision: 0.6809 - recall: 0.2301 - auc: 0.8100 - f1_score: 0.3404 - val_loss: 1.0214 - val_accuracy: 0.7678 - val_precision: 0.9011 - val_recall: 0.0802 - val_auc: 0.8068 - val_f1_score: 0.1435
#
# Epoch 00038: val_accuracy did not improve from 0.78666
# Epoch 39/100
# 129/129 [==============================] - 83s 640ms/step - loss: 0.9897 - accuracy: 0.7794 - precision: 0.6767 - recall: 0.2252 - auc: 0.8058 - f1_score: 0.3346 - val_loss: 1.0213 - val_accuracy: 0.7678 - val_precision: 0.9011 - val_recall: 0.0802 - val_auc: 0.8067 - val_f1_score: 0.1430
#
# Epoch 00039: val_accuracy did not improve from 0.78666
# Epoch 40/100
# 129/129 [==============================] - 83s 641ms/step - loss: 0.9880 - accuracy: 0.7825 - precision: 0.6922 - recall: 0.2338 - auc: 0.8112 - f1_score: 0.3500 - val_loss: 1.0207 - val_accuracy: 0.7681 - val_precision: 0.9022 - val_recall: 0.0811 - val_auc: 0.8079 - val_f1_score: 0.1452
#
# Epoch 00040: val_accuracy did not improve from 0.78666
# Epoch 41/100
# 129/129 [==============================] - 85s 659ms/step - loss: 0.9830 - accuracy: 0.7817 - precision: 0.6907 - recall: 0.2294 - auc: 0.8112 - f1_score: 0.3443 - val_loss: 1.0190 - val_accuracy: 0.7686 - val_precision: 0.9043 - val_recall: 0.0831 - val_auc: 0.8094 - val_f1_score: 0.1488
#
# Epoch 00041: val_accuracy did not improve from 0.78666
# Epoch 42/100
# 129/129 [==============================] - 83s 643ms/step - loss: 0.9880 - accuracy: 0.7824 - precision: 0.6974 - recall: 0.2289 - auc: 0.8098 - f1_score: 0.3476 - val_loss: 1.0215 - val_accuracy: 0.7681 - val_precision: 0.9022 - val_recall: 0.0811 - val_auc: 0.8073 - val_f1_score: 0.1450
#
# Epoch 00042: val_accuracy did not improve from 0.78666
# Epoch 43/100
# 129/129 [==============================] - 80s 621ms/step - loss: 0.9866 - accuracy: 0.7809 - precision: 0.6825 - recall: 0.2313 - auc: 0.8095 - f1_score: 0.3466 - val_loss: 1.0188 - val_accuracy: 0.7691 - val_precision: 0.9062 - val_recall: 0.0850 - val_auc: 0.8096 - val_f1_score: 0.1522
#
# Epoch 00043: val_accuracy did not improve from 0.78666
# Epoch 44/100
# 129/129 [==============================] - 80s 623ms/step - loss: 0.9882 - accuracy: 0.7822 - precision: 0.6941 - recall: 0.2304 - auc: 0.8108 - f1_score: 0.3416 - val_loss: 1.0192 - val_accuracy: 0.7686 - val_precision: 0.9043 - val_recall: 0.0831 - val_auc: 0.8077 - val_f1_score: 0.1472
#
# Epoch 00044: val_accuracy did not improve from 0.78666
# Epoch 45/100
# 129/129 [==============================] - 81s 625ms/step - loss: 0.9780 - accuracy: 0.7827 - precision: 0.6951 - recall: 0.2330 - auc: 0.8109 - f1_score: 0.3485 - val_loss: 1.0204 - val_accuracy: 0.7683 - val_precision: 0.9032 - val_recall: 0.0821 - val_auc: 0.8077 - val_f1_score: 0.1485
#
# Epoch 00045: val_accuracy did not improve from 0.78666
# Epoch 46/100
# 129/129 [==============================] - 82s 633ms/step - loss: 0.9908 - accuracy: 0.7813 - precision: 0.6904 - recall: 0.2269 - auc: 0.8084 - f1_score: 0.3429 - val_loss: 1.0224 - val_accuracy: 0.7678 - val_precision: 0.9011 - val_recall: 0.0802 - val_auc: 0.8076 - val_f1_score: 0.1434
#
# Epoch 00046: val_accuracy did not improve from 0.78666
# Epoch 47/100
# 129/129 [==============================] - 81s 629ms/step - loss: 0.9811 - accuracy: 0.7817 - precision: 0.6887 - recall: 0.2316 - auc: 0.8109 - f1_score: 0.3504 - val_loss: 1.0214 - val_accuracy: 0.7681 - val_precision: 0.9022 - val_recall: 0.0811 - val_auc: 0.8077 - val_f1_score: 0.1466
#
# Epoch 00047: val_accuracy did not improve from 0.78666
# Epoch 48/100
# 129/129 [==============================] - 81s 628ms/step - loss: 0.9993 - accuracy: 0.7775 - precision: 0.6623 - recall: 0.2245 - auc: 0.8076 - f1_score: 0.3389 - val_loss: 1.0187 - val_accuracy: 0.7688 - val_precision: 0.9053 - val_recall: 0.0841 - val_auc: 0.8092 - val_f1_score: 0.1501
#
# Epoch 00048: val_accuracy did not improve from 0.78666
# Epoch 49/100
# 129/129 [==============================] - 81s 629ms/step - loss: 0.9932 - accuracy: 0.7802 - precision: 0.6800 - recall: 0.2282 - auc: 0.8049 - f1_score: 0.3382 - val_loss: 1.0173 - val_accuracy: 0.7696 - val_precision: 0.9082 - val_recall: 0.0870 - val_auc: 0.8086 - val_f1_score: 0.1528
#
# Epoch 00049: val_accuracy did not improve from 0.78666
# Epoch 50/100
# 129/129 [==============================] - 81s 627ms/step - loss: 0.9885 - accuracy: 0.7818 - precision: 0.6867 - recall: 0.2343 - auc: 0.8084 - f1_score: 0.3454 - val_loss: 1.0194 - val_accuracy: 0.7683 - val_precision: 0.9032 - val_recall: 0.0821 - val_auc: 0.8075 - val_f1_score: 0.1468
#
# Epoch 00050: val_accuracy did not improve from 0.78666
# Epoch 51/100
# 129/129 [==============================] - 81s 626ms/step - loss: 0.9938 - accuracy: 0.7788 - precision: 0.6774 - recall: 0.2199 - auc: 0.8072 - f1_score: 0.3327 - val_loss: 1.0214 - val_accuracy: 0.7681 - val_precision: 0.9022 - val_recall: 0.0811 - val_auc: 0.8072 - val_f1_score: 0.1448
#
# Epoch 00051: val_accuracy did not improve from 0.78666
# Epoch 52/100
# 129/129 [==============================] - 83s 642ms/step - loss: 0.9851 - accuracy: 0.7815 - precision: 0.6880 - recall: 0.2304 - auc: 0.8073 - f1_score: 0.3408 - val_loss: 1.0203 - val_accuracy: 0.7681 - val_precision: 0.9022 - val_recall: 0.0811 - val_auc: 0.8062 - val_f1_score: 0.1441
#
# Epoch 00052: val_accuracy did not improve from 0.78666
# Epoch 53/100
# 129/129 [==============================] - 83s 644ms/step - loss: 0.9792 - accuracy: 0.7826 - precision: 0.6923 - recall: 0.2350 - auc: 0.8110 - f1_score: 0.3543 - val_loss: 1.0221 - val_accuracy: 0.7678 - val_precision: 0.9011 - val_recall: 0.0802 - val_auc: 0.8065 - val_f1_score: 0.1449
#
# Epoch 00053: val_accuracy did not improve from 0.78666
# Epoch 54/100
# 129/129 [==============================] - 82s 632ms/step - loss: 0.9843 - accuracy: 0.7814 - precision: 0.6912 - recall: 0.2272 - auc: 0.8107 - f1_score: 0.3423 - val_loss: 1.0215 - val_accuracy: 0.7681 - val_precision: 0.9022 - val_recall: 0.0811 - val_auc: 0.8081 - val_f1_score: 0.1464
#
# Epoch 00054: val_accuracy did not improve from 0.78666
# Epoch 55/100
# 129/129 [==============================] - 81s 626ms/step - loss: 0.9866 - accuracy: 0.7815 - precision: 0.6894 - recall: 0.2296 - auc: 0.8073 - f1_score: 0.3444 - val_loss: 1.0206 - val_accuracy: 0.7681 - val_precision: 0.9022 - val_recall: 0.0811 - val_auc: 0.8080 - val_f1_score: 0.1443
#
# Epoch 00055: val_accuracy did not improve from 0.78666
# Epoch 56/100
# 129/129 [==============================] - 82s 632ms/step - loss: 0.9901 - accuracy: 0.7814 - precision: 0.6865 - recall: 0.2308 - auc: 0.8086 - f1_score: 0.3492 - val_loss: 1.0198 - val_accuracy: 0.7681 - val_precision: 0.9022 - val_recall: 0.0811 - val_auc: 0.8081 - val_f1_score: 0.1441
#
# Epoch 00056: val_accuracy did not improve from 0.78666
# Epoch 57/100
# 129/129 [==============================] - 82s 635ms/step - loss: 0.9833 - accuracy: 0.7809 - precision: 0.6852 - recall: 0.2284 - auc: 0.8095 - f1_score: 0.3454 - val_loss: 1.0213 - val_accuracy: 0.7681 - val_precision: 0.9022 - val_recall: 0.0811 - val_auc: 0.8071 - val_f1_score: 0.1465
#
# Epoch 00057: val_accuracy did not improve from 0.78666
# Epoch 58/100
# 129/129 [==============================] - 80s 622ms/step - loss: 0.9865 - accuracy: 0.7812 - precision: 0.6864 - recall: 0.2296 - auc: 0.8092 - f1_score: 0.3406 - val_loss: 1.0198 - val_accuracy: 0.7683 - val_precision: 0.9032 - val_recall: 0.0821 - val_auc: 0.8083 - val_f1_score: 0.1466
#
# Epoch 00058: val_accuracy did not improve from 0.78666
# Epoch 59/100
# 129/129 [==============================] - 81s 626ms/step - loss: 0.9831 - accuracy: 0.7817 - precision: 0.6816 - recall: 0.2377 - auc: 0.8123 - f1_score: 0.3490 - val_loss: 1.0176 - val_accuracy: 0.7698 - val_precision: 0.9091 - val_recall: 0.0880 - val_auc: 0.8099 - val_f1_score: 0.1573
#
# Epoch 00059: val_accuracy did not improve from 0.78666
# Epoch 60/100
# 129/129 [==============================] - 81s 628ms/step - loss: 0.9814 - accuracy: 0.7804 - precision: 0.6817 - recall: 0.2284 - auc: 0.8103 - f1_score: 0.3432 - val_loss: 1.0182 - val_accuracy: 0.7688 - val_precision: 0.9053 - val_recall: 0.0841 - val_auc: 0.8094 - val_f1_score: 0.1502
#
# Epoch 00060: val_accuracy did not improve from 0.78666
# Epoch 61/100
# 129/129 [==============================] - 82s 637ms/step - loss: 0.9860 - accuracy: 0.7823 - precision: 0.6888 - recall: 0.2355 - auc: 0.8103 - f1_score: 0.3471 - val_loss: 1.0209 - val_accuracy: 0.7681 - val_precision: 0.9022 - val_recall: 0.0811 - val_auc: 0.8069 - val_f1_score: 0.1453
#
# Epoch 00061: val_accuracy did not improve from 0.78666
# Epoch 62/100
# 129/129 [==============================] - 82s 635ms/step - loss: 0.9906 - accuracy: 0.7804 - precision: 0.6786 - recall: 0.2308 - auc: 0.8058 - f1_score: 0.3453 - val_loss: 1.0161 - val_accuracy: 0.7698 - val_precision: 0.9010 - val_recall: 0.0890 - val_auc: 0.8087 - val_f1_score: 0.1564
#
# Epoch 00062: val_accuracy did not improve from 0.78666
# Epoch 63/100
# 129/129 [==============================] - 82s 633ms/step - loss: 0.9919 - accuracy: 0.7787 - precision: 0.6743 - recall: 0.2223 - auc: 0.8078 - f1_score: 0.3305 - val_loss: 1.0209 - val_accuracy: 0.7683 - val_precision: 0.9032 - val_recall: 0.0821 - val_auc: 0.8066 - val_f1_score: 0.1467
#
# Epoch 00063: val_accuracy did not improve from 0.78666
# Epoch 64/100
# 129/129 [==============================] - 84s 653ms/step - loss: 0.9867 - accuracy: 0.7812 - precision: 0.6864 - recall: 0.2296 - auc: 0.8061 - f1_score: 0.3451 - val_loss: 1.0219 - val_accuracy: 0.7678 - val_precision: 0.9011 - val_recall: 0.0802 - val_auc: 0.8061 - val_f1_score: 0.1432
#
# Epoch 00064: val_accuracy did not improve from 0.78666
# Epoch 65/100
# 129/129 [==============================] - 81s 627ms/step - loss: 0.9794 - accuracy: 0.7821 - precision: 0.6936 - recall: 0.2304 - auc: 0.8101 - f1_score: 0.3423 - val_loss: 1.0190 - val_accuracy: 0.7688 - val_precision: 0.9053 - val_recall: 0.0841 - val_auc: 0.8072 - val_f1_score: 0.1502
#
# Epoch 00065: val_accuracy did not improve from 0.78666
# Epoch 66/100
# 129/129 [==============================] - 81s 626ms/step - loss: 0.9889 - accuracy: 0.7812 - precision: 0.6866 - recall: 0.2299 - auc: 0.8090 - f1_score: 0.3454 - val_loss: 1.0222 - val_accuracy: 0.7678 - val_precision: 0.9011 - val_recall: 0.0802 - val_auc: 0.8067 - val_f1_score: 0.1446
#
# Epoch 00066: val_accuracy did not improve from 0.78666
# Epoch 67/100
# 129/129 [==============================] - 83s 643ms/step - loss: 0.9836 - accuracy: 0.7821 - precision: 0.6936 - recall: 0.2304 - auc: 0.8104 - f1_score: 0.3455 - val_loss: 1.0199 - val_accuracy: 0.7683 - val_precision: 0.9032 - val_recall: 0.0821 - val_auc: 0.8065 - val_f1_score: 0.1481
#
# Epoch 00067: val_accuracy did not improve from 0.78666
# Epoch 68/100
# 129/129 [==============================] - 82s 637ms/step - loss: 0.9889 - accuracy: 0.7813 - precision: 0.6857 - recall: 0.2311 - auc: 0.8090 - f1_score: 0.3469 - val_loss: 1.0204 - val_accuracy: 0.7681 - val_precision: 0.9022 - val_recall: 0.0811 - val_auc: 0.8071 - val_f1_score: 0.1450
#
# Epoch 00068: val_accuracy did not improve from 0.78666
# Epoch 69/100
# 129/129 [==============================] - 83s 641ms/step - loss: 0.9797 - accuracy: 0.7843 - precision: 0.7051 - recall: 0.2357 - auc: 0.8120 - f1_score: 0.3566 - val_loss: 1.0172 - val_accuracy: 0.7696 - val_precision: 0.9082 - val_recall: 0.0870 - val_auc: 0.8078 - val_f1_score: 0.1545
#
# Epoch 00069: val_accuracy did not improve from 0.78666
# Epoch 70/100
# 129/129 [==============================] - 82s 638ms/step - loss: 0.9902 - accuracy: 0.7812 - precision: 0.6869 - recall: 0.2291 - auc: 0.8101 - f1_score: 0.3467 - val_loss: 1.0172 - val_accuracy: 0.7696 - val_precision: 0.9000 - val_recall: 0.0880 - val_auc: 0.8098 - val_f1_score: 0.1577
#
# Epoch 00070: val_accuracy did not improve from 0.78666
# Epoch 71/100
# 129/129 [==============================] - 82s 633ms/step - loss: 0.9813 - accuracy: 0.7820 - precision: 0.6957 - recall: 0.2277 - auc: 0.8118 - f1_score: 0.3441 - val_loss: 1.0215 - val_accuracy: 0.7681 - val_precision: 0.9022 - val_recall: 0.0811 - val_auc: 0.8072 - val_f1_score: 0.1460
#
# Epoch 00071: val_accuracy did not improve from 0.78666
# Epoch 72/100
# 129/129 [==============================] - 83s 640ms/step - loss: 0.9904 - accuracy: 0.7806 - precision: 0.6778 - recall: 0.2335 - auc: 0.8068 - f1_score: 0.3471 - val_loss: 1.0176 - val_accuracy: 0.7693 - val_precision: 0.9072 - val_recall: 0.0860 - val_auc: 0.8103 - val_f1_score: 0.1544
#
# Epoch 00072: val_accuracy did not improve from 0.78666
# Epoch 73/100
# 129/129 [==============================] - 82s 636ms/step - loss: 0.9862 - accuracy: 0.7829 - precision: 0.7006 - recall: 0.2301 - auc: 0.8110 - f1_score: 0.3477 - val_loss: 1.0193 - val_accuracy: 0.7686 - val_precision: 0.9043 - val_recall: 0.0831 - val_auc: 0.8086 - val_f1_score: 0.1474
#
# Epoch 00073: val_accuracy did not improve from 0.78666
# Epoch 74/100
# 129/129 [==============================] - 80s 623ms/step - loss: 0.9841 - accuracy: 0.7835 - precision: 0.7023 - recall: 0.2326 - auc: 0.8115 - f1_score: 0.3501 - val_loss: 1.0189 - val_accuracy: 0.7686 - val_precision: 0.9043 - val_recall: 0.0831 - val_auc: 0.8084 - val_f1_score: 0.1494
#
# Epoch 00074: val_accuracy did not improve from 0.78666
# Epoch 75/100
# 129/129 [==============================] - 80s 621ms/step - loss: 0.9840 - accuracy: 0.7798 - precision: 0.6773 - recall: 0.2279 - auc: 0.8091 - f1_score: 0.3371 - val_loss: 1.0195 - val_accuracy: 0.7686 - val_precision: 0.9043 - val_recall: 0.0831 - val_auc: 0.8077 - val_f1_score: 0.1492
#
# Epoch 00075: val_accuracy did not improve from 0.78666
# Epoch 76/100
# 129/129 [==============================] - 80s 622ms/step - loss: 0.9828 - accuracy: 0.7833 - precision: 0.7046 - recall: 0.2294 - auc: 0.8114 - f1_score: 0.3471 - val_loss: 1.0205 - val_accuracy: 0.7683 - val_precision: 0.9032 - val_recall: 0.0821 - val_auc: 0.8070 - val_f1_score: 0.1470
#
# Epoch 00076: val_accuracy did not improve from 0.78666
# Epoch 77/100
# 129/129 [==============================] - 81s 624ms/step - loss: 0.9852 - accuracy: 0.7825 - precision: 0.6930 - recall: 0.2330 - auc: 0.8063 - f1_score: 0.3524 - val_loss: 1.0202 - val_accuracy: 0.7683 - val_precision: 0.9032 - val_recall: 0.0821 - val_auc: 0.8063 - val_f1_score: 0.1478
#
# Epoch 00077: val_accuracy did not improve from 0.78666
# Epoch 78/100
# 129/129 [==============================] - 82s 635ms/step - loss: 0.9878 - accuracy: 0.7817 - precision: 0.6909 - recall: 0.2296 - auc: 0.8097 - f1_score: 0.3444 - val_loss: 1.0213 - val_accuracy: 0.7681 - val_precision: 0.9022 - val_recall: 0.0811 - val_auc: 0.8069 - val_f1_score: 0.1456
#
# Epoch 00078: val_accuracy did not improve from 0.78666
# Epoch 79/100
# 129/129 [==============================] - 80s 623ms/step - loss: 0.9911 - accuracy: 0.7791 - precision: 0.6737 - recall: 0.2257 - auc: 0.8079 - f1_score: 0.3383 - val_loss: 1.0178 - val_accuracy: 0.7691 - val_precision: 0.9062 - val_recall: 0.0850 - val_auc: 0.8069 - val_f1_score: 0.1515
#
# Epoch 00079: val_accuracy did not improve from 0.78666
# Epoch 80/100
# 129/129 [==============================] - 80s 619ms/step - loss: 0.9913 - accuracy: 0.7802 - precision: 0.6811 - recall: 0.2272 - auc: 0.8063 - f1_score: 0.3406 - val_loss: 1.0200 - val_accuracy: 0.7683 - val_precision: 0.9032 - val_recall: 0.0821 - val_auc: 0.8077 - val_f1_score: 0.1484
#
# Epoch 00080: val_accuracy did not improve from 0.78666
# Epoch 81/100
# 129/129 [==============================] - 80s 619ms/step - loss: 0.9929 - accuracy: 0.7794 - precision: 0.6707 - recall: 0.2311 - auc: 0.8076 - f1_score: 0.3452 - val_loss: 1.0186 - val_accuracy: 0.7691 - val_precision: 0.9062 - val_recall: 0.0850 - val_auc: 0.8086 - val_f1_score: 0.1514
#
# Epoch 00081: val_accuracy did not improve from 0.78666
# Epoch 82/100
# 129/129 [==============================] - 79s 614ms/step - loss: 0.9886 - accuracy: 0.7812 - precision: 0.6880 - recall: 0.2286 - auc: 0.8084 - f1_score: 0.3441 - val_loss: 1.0214 - val_accuracy: 0.7683 - val_precision: 0.9032 - val_recall: 0.0821 - val_auc: 0.8069 - val_f1_score: 0.1486
#
# Epoch 00082: val_accuracy did not improve from 0.78666
# Epoch 83/100
# 129/129 [==============================] - 80s 623ms/step - loss: 0.9907 - accuracy: 0.7819 - precision: 0.6910 - recall: 0.2308 - auc: 0.8085 - f1_score: 0.3423 - val_loss: 1.0229 - val_accuracy: 0.7678 - val_precision: 0.9011 - val_recall: 0.0802 - val_auc: 0.8063 - val_f1_score: 0.1445
#
# Epoch 00083: val_accuracy did not improve from 0.78666
# Epoch 84/100
# 129/129 [==============================] - 83s 643ms/step - loss: 0.9922 - accuracy: 0.7814 - precision: 0.6857 - recall: 0.2316 - auc: 0.8077 - f1_score: 0.3425 - val_loss: 1.0206 - val_accuracy: 0.7681 - val_precision: 0.9022 - val_recall: 0.0811 - val_auc: 0.8077 - val_f1_score: 0.1448
#
# Epoch 00084: val_accuracy did not improve from 0.78666
# Epoch 85/100
# 129/129 [==============================] - 84s 653ms/step - loss: 0.9865 - accuracy: 0.7803 - precision: 0.6807 - recall: 0.2284 - auc: 0.8104 - f1_score: 0.3382 - val_loss: 1.0191 - val_accuracy: 0.7688 - val_precision: 0.9053 - val_recall: 0.0841 - val_auc: 0.8083 - val_f1_score: 0.1486
#
# Epoch 00085: val_accuracy did not improve from 0.78666
# Epoch 86/100
# 129/129 [==============================] - 82s 637ms/step - loss: 0.9841 - accuracy: 0.7823 - precision: 0.6958 - recall: 0.2294 - auc: 0.8103 - f1_score: 0.3443 - val_loss: 1.0222 - val_accuracy: 0.7678 - val_precision: 0.9011 - val_recall: 0.0802 - val_auc: 0.8059 - val_f1_score: 0.1448
#
# Epoch 00086: val_accuracy did not improve from 0.78666
# Epoch 87/100
# 129/129 [==============================] - 81s 629ms/step - loss: 0.9934 - accuracy: 0.7784 - precision: 0.6691 - recall: 0.2250 - auc: 0.8051 - f1_score: 0.3329 - val_loss: 1.0189 - val_accuracy: 0.7688 - val_precision: 0.9053 - val_recall: 0.0841 - val_auc: 0.8089 - val_f1_score: 0.1496
#
# Epoch 00087: val_accuracy did not improve from 0.78666
# Epoch 88/100
# 129/129 [==============================] - 82s 638ms/step - loss: 0.9922 - accuracy: 0.7803 - precision: 0.6821 - recall: 0.2267 - auc: 0.8075 - f1_score: 0.3367 - val_loss: 1.0211 - val_accuracy: 0.7681 - val_precision: 0.9022 - val_recall: 0.0811 - val_auc: 0.8077 - val_f1_score: 0.1458
#
# Epoch 00088: val_accuracy did not improve from 0.78666
# Epoch 89/100
# 129/129 [==============================] - 82s 634ms/step - loss: 0.9892 - accuracy: 0.7791 - precision: 0.6795 - recall: 0.2204 - auc: 0.8093 - f1_score: 0.3327 - val_loss: 1.0200 - val_accuracy: 0.7683 - val_precision: 0.9032 - val_recall: 0.0821 - val_auc: 0.8084 - val_f1_score: 0.1467
#
# Epoch 00089: val_accuracy did not improve from 0.78666
# Epoch 90/100
# 129/129 [==============================] - 81s 631ms/step - loss: 0.9957 - accuracy: 0.7792 - precision: 0.6770 - recall: 0.2230 - auc: 0.8082 - f1_score: 0.3363 - val_loss: 1.0222 - val_accuracy: 0.7678 - val_precision: 0.9011 - val_recall: 0.0802 - val_auc: 0.8063 - val_f1_score: 0.1438
#
# Epoch 00090: val_accuracy did not improve from 0.78666
# Epoch 91/100
# 129/129 [==============================] - 82s 633ms/step - loss: 0.9939 - accuracy: 0.7796 - precision: 0.6835 - recall: 0.2208 - auc: 0.8067 - f1_score: 0.3351 - val_loss: 1.0191 - val_accuracy: 0.7686 - val_precision: 0.9043 - val_recall: 0.0831 - val_auc: 0.8087 - val_f1_score: 0.1496
#
# Epoch 00091: val_accuracy did not improve from 0.78666
# Epoch 92/100
# 129/129 [==============================] - 83s 640ms/step - loss: 0.9911 - accuracy: 0.7826 - precision: 0.6966 - recall: 0.2308 - auc: 0.8084 - f1_score: 0.3430 - val_loss: 1.0171 - val_accuracy: 0.7693 - val_precision: 0.8990 - val_recall: 0.0870 - val_auc: 0.8106 - val_f1_score: 0.1549
#
# Epoch 00092: val_accuracy did not improve from 0.78666
# Epoch 93/100
# 129/129 [==============================] - 83s 644ms/step - loss: 0.9897 - accuracy: 0.7800 - precision: 0.6822 - recall: 0.2247 - auc: 0.8055 - f1_score: 0.3346 - val_loss: 1.0211 - val_accuracy: 0.7681 - val_precision: 0.9022 - val_recall: 0.0811 - val_auc: 0.8069 - val_f1_score: 0.1458
#
# Epoch 00093: val_accuracy did not improve from 0.78666
# Epoch 94/100
# 129/129 [==============================] - 83s 640ms/step - loss: 0.9821 - accuracy: 0.7815 - precision: 0.6886 - recall: 0.2299 - auc: 0.8095 - f1_score: 0.3481 - val_loss: 1.0206 - val_accuracy: 0.7681 - val_precision: 0.9022 - val_recall: 0.0811 - val_auc: 0.8079 - val_f1_score: 0.1456
#
# Epoch 00094: val_accuracy did not improve from 0.78666
# Epoch 95/100
# 129/129 [==============================] - 83s 642ms/step - loss: 0.9868 - accuracy: 0.7816 - precision: 0.6916 - recall: 0.2282 - auc: 0.8102 - f1_score: 0.3398 - val_loss: 1.0200 - val_accuracy: 0.7681 - val_precision: 0.9022 - val_recall: 0.0811 - val_auc: 0.8078 - val_f1_score: 0.1468
#
# Epoch 00095: val_accuracy did not improve from 0.78666
# Epoch 96/100
# 129/129 [==============================] - 83s 639ms/step - loss: 0.9889 - accuracy: 0.7804 - precision: 0.6831 - recall: 0.2267 - auc: 0.8080 - f1_score: 0.3360 - val_loss: 1.0222 - val_accuracy: 0.7681 - val_precision: 0.9022 - val_recall: 0.0811 - val_auc: 0.8067 - val_f1_score: 0.1463
#
# Epoch 00096: val_accuracy did not improve from 0.78666
# Epoch 97/100
# 129/129 [==============================] - 84s 649ms/step - loss: 0.9919 - accuracy: 0.7804 - precision: 0.6812 - recall: 0.2289 - auc: 0.8074 - f1_score: 0.3435 - val_loss: 1.0226 - val_accuracy: 0.7676 - val_precision: 0.9000 - val_recall: 0.0792 - val_auc: 0.8059 - val_f1_score: 0.1411
#
# Epoch 00097: val_accuracy did not improve from 0.78666
# Epoch 98/100
# 129/129 [==============================] - 83s 643ms/step - loss: 0.9833 - accuracy: 0.7796 - precision: 0.6827 - recall: 0.2216 - auc: 0.8090 - f1_score: 0.3359 - val_loss: 1.0199 - val_accuracy: 0.7688 - val_precision: 0.9053 - val_recall: 0.0841 - val_auc: 0.8072 - val_f1_score: 0.1507
#
# Epoch 00098: val_accuracy did not improve from 0.78666
# Epoch 99/100
# 129/129 [==============================] - 83s 642ms/step - loss: 0.9827 - accuracy: 0.7825 - precision: 0.6930 - recall: 0.2335 - auc: 0.8108 - f1_score: 0.3529 - val_loss: 1.0207 - val_accuracy: 0.7681 - val_precision: 0.9022 - val_recall: 0.0811 - val_auc: 0.8073 - val_f1_score: 0.1443
#
# Epoch 00099: val_accuracy did not improve from 0.78666
# Epoch 100/100
# 129/129 [==============================] - 83s 643ms/step - loss: 0.9833 - accuracy: 0.7829 - precision: 0.7000 - recall: 0.2306 - auc: 0.8115 - f1_score: 0.3504 - val_loss: 1.0216 - val_accuracy: 0.7678 - val_precision: 0.9011 - val_recall: 0.0802 - val_auc: 0.8062 - val_f1_score: 0.1445
#
# Epoch 00100: val_accuracy did not improve from 0.78666

# %%
# model.save_weights("/content/drive/MyDrive/Garvin/IEEE/Alzheimer's Disease Classification/model_densenet_wavelet.hdf5")

# %%
model.load_weights("/content/drive/MyDrive/Garvin/IEEE/Alzheimer's Disease Classification/model_densenet_wavelet.hdf5")

# %%
def Train_Val_Plot(acc,val_acc,loss,val_loss,auc,val_auc,precision,val_precision):
    
    fig, (ax1, ax2,ax3,ax4) = plt.subplots(1,4, figsize= (20,5))
    fig.suptitle(" MODEL'S METRICS VISUALIZATION ")

    ax1.plot(range(1, len(acc) + 1), acc)
    ax1.plot(range(1, len(val_acc) + 1), val_acc)
    ax1.set_title('History of Accuracy')
    ax1.set_xlabel('Epochs')
    ax1.set_ylabel('Accuracy')
    ax1.legend(['training', 'validation'])


    ax2.plot(range(1, len(loss) + 1), loss)
    ax2.plot(range(1, len(val_loss) + 1), val_loss)
    ax2.set_title('History of Loss')
    ax2.set_xlabel('Epochs')
    ax2.set_ylabel('Loss')
    ax2.legend(['training', 'validation'])
    
    ax3.plot(range(1, len(auc) + 1), auc)
    ax3.plot(range(1, len(val_auc) + 1), val_auc)
    ax3.set_title('History of AUC')
    ax3.set_xlabel('Epochs')
    ax3.set_ylabel('AUC')
    ax3.legend(['training', 'validation'])
    
    ax4.plot(range(1, len(precision) + 1), precision)
    ax4.plot(range(1, len(val_precision) + 1), val_precision)
    ax4.set_title('History of Precision')
    ax4.set_xlabel('Epochs')
    ax4.set_ylabel('Precision')
    ax4.legend(['training', 'validation'])
    
  
    plt.show()
    

Train_Val_Plot(history.history['accuracy'],history.history['val_accuracy'],
               history.history['loss'],history.history['val_loss'],
               history.history['auc'],history.history['val_auc'],
               history.history['precision'],history.history['val_precision']
              )

# %%
scores = model.evaluate(test_dataset)
# Out:
# 40/40 [==============================] - 11s 265ms/step - loss: 1.0338 - accuracy: 0.7543 - precision: 0.5696 - recall: 0.0704 - auc: 0.7880 - f1_score: 0.1231

# %%
print("Accuracy = ", scores[1])
print("Precision = ", scores[2])
print("Recall = ", scores[3])
print("AUC = ", scores[4])
print("F1 = ", scores[5])
# Out:
# Accuracy =  0.7543002367019653
# Precision =  0.5696202516555786
# Recall =  0.0703674778342247
# AUC =  0.7880269885063171
# F1 =  0.12310675531625748
